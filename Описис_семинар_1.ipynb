# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniilSysoev/opisis_sem_1/blob/main/%D0%9E%D0%BF%D0%B8%D1%81%D0%B8%D1%81_%D1%81%D0%B5%D0%BC%D0%B8%D0%BD%D0%B0%D1%80_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Построение модели функции синуса с заданным количеством шагов дискретизации</h1>

# %% [markdown]
# <h3>Введем необходимые библиотеки для отображения и построения функции синуса</h3>

# %%
import matplotlib.pyplot as plt
import matplotlib.markers as mrk
import numpy as np

# %% [markdown]
# <h3>Напишем функции для дискретизации синуса</h3>

# %%
def discr_sin(f, T, n):
  x = np.linspace(0, T, n)
  y = np.sin(2*np.pi*f*x)
  return (x, y)

# %% [markdown]
# <h3>Напишем функцию для визуализации полученной функции<h3>

# %%
def plot_out(func):
  plt.plot(*func)

# %% [markdown]
# <h3>Ниже приведен график для отображения синуса через введенные опорную частоту, временной интервал и число временных отсчетов.</h3>
# <h5>Входные данные:<br>f=10<br>T=1<br>n=30</h5>

# %%
f = float(input())
T = float(input())
n = int(input())
print(f'f={f}, T={T}, n={n}')
func = discr_sin(f, T, n)
plot_out(func)
# Out:
# 10
# 1
# 30
# f=10.0, T=1.0, n=30

# %% [markdown]
# <h3>Второй график</h3>
# <h5>Входные данные:<br>f=10<br>T=1<br>n=100</h5>

# %%
f = float(input())
T = float(input())
n = int(input())
print(f'f={f}, T={T}, n={n}')
func = discr_sin(f, T, n)
plot_out(func)
# Out:
# 10
# 1
# 100
# f=10.0, T=1.0, n=100

# %% [markdown]
# <h3>Третий график</h3> <h5>Входные данные:<br>f=10<br>T=1<br>n=200</h5>

# %%
f = float(input())
T = float(input())
n = int(input())
print(f'f={f}, T={T}, n={n}')
func = discr_sin(f, T, n)
plot_out(func)
# Out:
# 10
# 1
# 200
# f=10.0, T=1.0, n=200

# %% [markdown]
# <h1>Квантование переодического сигнала</h1>

# %% [markdown]
# <h3>Первый график</h3>
# <h5>Входные данные:<br>f=1<br>T=50<br>n=50</h5>

# %%
f = float(input())
T = float(input())
n = int(input())
print(f"f={f}, T={T}, n={n}")
x = np.linspace(0, T, n)
plt.vlines(x, 0, np.sin(f*x), color='blue')
plt.plot(x, np.sin(f*x), 'o', color='blue')
# Out:
# 1
# 50
# 50
# f=1.0, T=50.0, n=50

# %% [markdown]
# <h3>Второй график</h3>
# <h5>Входные данные:<br>f=1<br>T=20<br>n=50</h5>

# %%
f = float(input())
T = float(input())
n = int(input())
print(f"f={f}, T={T}, n={n}")
x = np.linspace(0, T, n)
plt.vlines(x, 0, np.sin(f*x), color='blue')
plt.plot(x, np.sin(f*x), 'o', color='blue')
# Out:
# 1
# 20
# 50
# f=1.0, T=20.0, n=50

# %% [markdown]
# <h3>Третий график</h3>
# <h5>Входные данные:<br>f=1<br>T=10<br>n=50</h5>

# %%
f = float(input())
T = float(input())
n = int(input())
print(f"f={f}, T={T}, n={n}")
x = np.linspace(0, T, n)
plt.vlines(x, 0, np.sin(f*x), color='blue')
plt.plot(x, np.sin(f*x), 'o', color='blue')
# Out:
# 1
# 10
# 50
# f=1.0, T=10.0, n=50
